# %%
from crowemi_trades.storage.s3_storage import S3Storage

stor = S3Storage()

# %%
from crowemi_trades.storage.s3_storage import S3Storage

stor = S3Storage()
