# %%
from crowemi_trades.storage.s3_storage import S3Storage
import talib

storage = S3Storage()

functions = talib.get_functions()
print(functions)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 from crowemi_trades.storage.s3_storage import S3Storage
#       2 import talib
# ----> 4 storage = S3Storage()
#       6 functions = talib.get_functions()
#       7 print(functions)
#
# File ~/code/personal/crowemi-trades/crowemi_trades/storage/s3_storage.py:24, in S3Storage.__init__(self, access_key, secret_access_key, region)
#      21 self.secret_access_key = os.getenv("AWS_SECRET_ACCESS_KEY", secret_access_key)
#      22 self.region = os.getenv("AWS_REGION", "us-west-2")
# ---> 24 super().__init__(type="aws", region="us-west-2")
#      26 self.aws_client = AwsS3(region)
#      27 self._create_file_system()
#
# File ~/code/personal/crowemi-trades/crowemi_trades/storage/base_storage.py:20, in BaseStorage.__init__(self, type, region)
#      19 def __init__(self, type: str, region: str) -> None:
# ...
